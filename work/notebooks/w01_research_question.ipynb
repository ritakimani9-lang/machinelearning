# %% [markdown]
# <a href="https://colab.research.google.com/github/ritakimani9-lang/machinelearning/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ritakimani9-lang/machinelearning/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# i'm choosing lane 1 : Ranking signal analysis
# This lane asks which safe content and search signals (impressions, clicks, position, freshness, word count, engagement, etc.) are associated with visibility, clicks, engagement, or movement. I'm starting here because it's foundational — before building a scoring system (Lane 2) or clustering pages into types (Lane 3), I want to understand which of the ~20+ available signals actually carry real information, and which are noise. It's also lower-risk to start with since it's exploratory rather than committing early to one specific target.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
# Decision this improves: Out of dozens of available metrics, which 3-5 signals are actually worth a content strategist's attention when deciding what to investigate first?
# Who acts, and how: A content strategist or reviewer, when triaging limited review time, would use my signal report to focus on the handful of metrics that show real association with decline/engagement — instead of treating all signals as equally important.
#
#
# Cost of a wrong call: If I flag a signal as meaningful when it's actually noise, future scoring work (Lane 2) risks being built on a false lead. If I miss a real signal, a genuinely useful lever gets ignored. Since this lane is exploratory (not acting on individual pages directly), the cost per mistake is lower than in a lane that directly ranks pages for action — my output is directional evidence, not a final decision.
# Why data/ML, not just intuition: With 20+ signals and ~30,000 rows, hand-picking "important" signals by gut feeling risks missing non-obvious patterns (e.g. how freshness and position tier interact) that only show up when you actually look at grouped numbers.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real n)
# Out of 30,000 pages, 54.2% are labeled "down" (16,262 declining) — a near-balanced split, not a rare event. Comparing declining vs. non-declining pages: declining pages show slightly lower average impressions (4,919 vs 5,533), slightly better average position (15.9 vs 16.8), and are somewhat younger (236 vs 280 days). The direction on position and age is counterintuitive — I expected declining pages to be older and worse-ranked — suggesting these signals aren't strong individual predictors alone, or a more complex interaction exists that a simple group-mean comparison can't capture. This is worth studying further: 30,000 rows and a near-even class split give enough data to look for real patterns.

# %%
import requests
from io import StringIO

# Direct URL to the raw CSV file on GitHub
github_csv_url = "https://raw.githubusercontent.com/ritakimani9-lang/machinelearning/refs/heads/main/data/raw/content_refresh_anonymized.csv"

# Download the CSV content
response = requests.get(github_csv_url)
response.raise_for_status()  # Raise an exception for bad status codes

# Read the content into a pandas DataFrame
df = pd.read_csv(StringIO(response.text))

print("Total rows:", len(df))
print(df["trend_direction"].value_counts())

# Compare a couple of signals between declining vs non-declining pages
df["is_declining"] = df["trend_direction"] == "down"
print(df.groupby("is_declining")[["impressions_90d", "avg_position", "content_age_days"]].mean())
# Out:
# Total rows: 30000
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#               impressions_90d  avg_position  content_age_days
# is_declining
# False             5533.310962     16.823060        279.829451
# True              4919.097466     15.936305        236.178637

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# Can say: Observed associations within this anonymized 30k-row sample — directional patterns like "declining pages tend to show X on average."
# Can't say: That any signal causes decline (this is observational, not an experiment); that I've found a Google ranking algorithm factor; that these patterns generalize beyond this sample; that a mean difference this small is necessarily meaningful rather than noise, since I haven't tested for statistical significance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
